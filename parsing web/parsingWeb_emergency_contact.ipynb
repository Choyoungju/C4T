# %%
# coding: utf-8
import pandas
import requests
import csv
import json
import xmltodict
import re

url = "http://apis.data.go.kr/1262000/ContactService/getContactList"
sKey = '24C%2FxddyRCTiVMSQN7xGhrvODlbKHfrGG%2Bg4ryyKXO8GGVjexQKYpkSH7PHU6MamZZ9qa07Dq9h25bAohPX3Jg%3D%3D'

code_list = []
with open("isoCode.csv", 'r') as f:
    csvreader = csv.reader(f)
    for row in csvreader:
        code = row[0].split(',')
        code_list.append(code[0])

p = re.compile('[a-zA-Z]')
code_list = code_list[1:]

for iso in code_list[:10]:
    payload = {'serviceKey': sKey,'isoCode1':iso}
    payload_str = "&".join("%s=%s" % (k,v) for k,v in payload.items())

    resp = requests.get(url,params = payload_str)
    xmlString = resp.text
    print(xmlString)
    print()
    #dt1 = xmltodict.parse(xmlString,encoding= 'utf-8')
    #if dt1.get('response'):
    #    if dt1['response']['body']['items']:
    #        dt2 = dt1['response']['body']['items']['item']
    #        del dt2['contact']
    #    jsonString = json.dumps(dt2, indent=2, ensure_ascii=False)

    #   with open("emergency_contact.txt", 'a',encoding='utf-8') as f:
    #       f.write(jsonString)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><contact>&lt;div&gt;&lt;h3 class=&quot;tit&quot;&gt;대사관 연락처&lt;/h3&gt;[주가나한국대사관]&lt;br&gt;ㅇ 주소: No.10, Fifth Avenue Extension, Cantonments, P.O.Box GP 13700, Accra, Ghana&lt;br&gt;ㅇ 대표번호 : +(233) 0302-776-157&amp;nbsp;, 7533 ,9921&lt;br&gt;ㅇ 긴급연락처 : +(233) 244-321-858&lt;br&gt;ㅇ 팩스 : +233 (0)302-772-313&lt;br&gt;ㅇ E mail : &lt;a href=&quot;mailto:ghana@mofa.go.kr&quot;&gt;ghana@mofa.go.kr&lt;/a&gt;&lt;br&gt;&lt;br&gt;&lt;/div&gt;</contact><continent>중동/아프리카</continent><countryEnName>Ghana</countryEnName><countryName>가나</countryName><id>390</id><imgUrl>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=FILE_000000000010504&amp;file_sn=1</imgUrl><imgUrl2>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=FILE_000000000010504&amp;file_sn=3</imgUrl2><wrtDt>2014-08-04</wrtDt></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>1</totalCount></body></response>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><contact>&lt;div&gt;&lt;h3 class=&quot;tit&quot;&gt;&lt;span id=&quot;_SESpan_StartCaret&quot;&gt;&lt;/span&gt;&lt;span id=&quot;_SESpan_StartCaret&quot;&gt;&lt;/span&gt;긴급 구조&lt;/h3&gt;ㅇ 경찰 1720, 소방서 18, 공안 13, 앰뷸런스 요청 1466, 한인회 0677-1748&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &#xD;
# &lt;h3 class=&quot;tit&quot;&gt;의료기관 및 경찰서 연락처&lt;/h3&gt;ㅇ 경찰 : 0172-0037, 0176-0445(긴급 연락처 177 혹은 13)&lt;br&gt;&#xD;
# ㅇ 소방서 : 0176-1520, 017 4-0955 (긴급 연락처 18) &lt;br&gt;&#xD;
# ㅇ 병원 : 0179-0000 혹은 1466(앰뷸런스), 0173-2771 (Jeanne Ebori)&lt;br&gt;&#xD;
# ㅇ 한인회 : 0677-1748&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# [한국에서 걸 때]&lt;br&gt;&#xD;
# ㅇ 경찰 : (00241) 0172-0037, (00241) 0176-0445 &lt;br&gt;&#xD;
# ㅇ 소방서 : (00241) 0176-1520, (00241) 0174-0955 &lt;br&gt;&#xD;
# ㅇ 병원 : (00241) 0179-0000 혹은 1466(앰뷸런스), 0173-2771 (Jeanne Ebori 병원) &lt;br&gt;&#xD;
# ㅇ 한인회 : (00241) 0677-1748&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &#xD;
# &lt;h3 class=&quot;tit&quot;&gt;대사관 연락처&lt;/h3&gt;&lt;p&gt;[주가봉한국대사관]&lt;br&gt;&#xD;
# ㅇ 주소 : B.P. 2620 Libreville, GABON&lt;br&gt;&#xD;
# ㅇ 대표번호 : (한국에서 거실 때 00241) 0173-4000 / 0530-1900&lt;br&gt;&#xD;
# ㅇ 긴급연락처 : (241) 0750-7822&lt;br&gt;&#xD;
# ㅇ 팩스번호 : (241) 0145-2322&lt;/p&gt;&lt;p&gt;&lt;br&gt;&#xD;
# &lt;img alt=&quot;&quot; src=&quot;http://25.media.tumblr.com/dadd603694462e8934f7df846e711cb7/tumblr_mtkni0Vajm1rn8wzmo2_500.jpg&quot;&gt;&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ 오시는 길 : Sablire(사블리에)지역에 있는 Beach club을 지나 100m 직진하시면 좌측에 흰 건물과 파란 지붕으로 축조된 대사관이 보입니다.&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 공항에서 택시 승차시 : 운전사에게 A la Sablire, cent metre aprs le Beach-club, sil vous plait. (아 라 싸블리에, 썽 메트르 아프레 르 비치클럽, 씰부쁠레) 라고 말씀하신 뒤 현지화 1,000 CFA 정도를 지불하시면 됩니다.&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 자가용 이용 시 : 공항을 빠져나와 우회전 후 직진 → 로터리에서 좌측으로 돌면 보이는 골목으로 진입하여 직진하다가 우회전→5분 정도 직진하면 우측에 Beach Club이 보임 →100m 정도 더 전진하면 좌측에 흰 건물에 파란 지붕으로 축조된 대사관이 보임.&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# [근무시간]&lt;/p&gt;&lt;p&gt;&#xD;
# ㅇ 월 ~ 금 : 오전 8:00~12:00, 오후 13:00~16:00 (점심시간 : 12:00~13:00)&lt;/p&gt;&lt;/div&gt;</contact><continent>중동/아프리카</continent><countryEnName>Gabon</countryEnName><countryName>가봉</countryName><id>2</id><imgUrl>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_2&amp;file_sn=1</imgUrl><imgUrl2>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_2&amp;file_sn=3</imgUrl2><wrtDt>2010-02-03</wrtDt></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>1</totalCount></body></response>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><contact>&lt;div&gt;&lt;h3 class=&quot;tit marz&quot;&gt;긴급연락처&lt;/h3&gt;ㅇ 비상사태 발생 시 도움을 청할 수 있는 긴급 호출번호는 국번 없이 911 입니다. 912는 화재발생시, 913은 앰블런스 사용시 이용 가능합니다.&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &#xD;
# &lt;h3 class=&quot;tit&quot;&gt;의료기관 연락처&lt;/h3&gt;ㅇ 보건위생관련 말라리아가 내륙의 풍토병이며, 콜레라, 뎅기열, 장티푸스에 걸릴 위험이 있어 관련 예방접종이 요구됩니다. &lt;br&gt;&#xD;
# ㅇ 913은 앰블런스 사용시 이용 가능합니다. &lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &#xD;
# &lt;h3 class=&quot;tit&quot;&gt;대사관 연락처&lt;/h3&gt;※ 가이아나에는 우리대사관이 없으며, 주베네수엘라한국대사관이 겸임하고 있습니다.&lt;br&gt;&#xD;
# ㅇ 주소 : Av. Francisco de Miranda, Centro Lido, Torre B, Piso 9, Ofic.91-92-B, El Rosal, Caracas, Venezuela&lt;br&gt;&#xD;
# ㅇ 대표번호 : (58-212) 954-1270&lt;br&gt;&#xD;
# ㅇ 팩스 : (58-212)954-0619&lt;br&gt;&#xD;
# ㅇ E-mail : &lt;a href=&quot;mailto:venezuela@mofa.go.kr&quot;&gt;venezuela@mofa.go.kr&lt;/a&gt;&#xD;
# &lt;br&gt;ㅇ&amp;nbsp;긴급연락처 : (58) 414-241-0056, (58) 412-309-3247, (58) 414-155-4715&lt;br&gt;&lt;/div&gt;</contact><continent>미주</continent><countryEnName>Guyana</countryEnName><countryName>가이아나공화국</countryName><id>315</id><imgUrl>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_315&amp;file_sn=1</imgUrl><imgUrl2>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_315&amp;file_sn=3</imgUrl2><wrtDt>2010-02-02</wrtDt></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>1</totalCount></body></response>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><contact>&lt;div&gt;&lt;h3 class=&quot;tit&quot;&gt;긴급 연락처&lt;/h3&gt;ㅇ 경찰 신고 : (+220) 117 &lt;br&gt;&#xD;
# ㅇ 응급 신고(구급차) : (+220) 116 &lt;br&gt;&#xD;
# ㅇ 화재 신고 : (+220) 118&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &#xD;
# &lt;h3 class=&quot;tit&quot;&gt;의료기관 연락처&lt;/h3&gt;[주요 의료 시설]&lt;br&gt;&#xD;
# ㅇ MEDICAL RESEARCH COUNCIL (MRC)&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 주소 : Atlantic Boulevard Serrekunda, Gambia&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 전화번호 : (+220) 449 5442, 449 5444&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ AHMADIYA HOSPITAL&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 주소 : Serrekunda, Kombo Sillah Drive&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 전화번호 : (일반) (+220) 439 0621/3, 439 0620/2/4 (치과) (+220) 439 1183 &lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ ROYAL VICTORIA TEACHING HOSPITAL&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 주소 : Independence Drive, Banjul&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 전화번호 : (+220) 422 8224/5/6/7 &lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ WESTFIELD CLINIC&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 주소 : Serrekunda/Westfield Junction&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 전화번호 : (+220) 439 3523, 439 2213&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ LAMTORO MEDICAL CENTRE&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 주소 : Badala Parkway, Kololi&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 전화번호 : (+220) 446 0934, 446 0596 &lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ MOMODOU MUSA MEMORIAL CLINIC&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Serekunda/London Corner Clinic : (+220) 437 1683&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Banjul Clinic : (+220) 422 4320 &lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ AFRICMED CLINIC&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 주소 : Senegambia Junction Kombo Kololi&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 전화번호 : (+220) 446 5359, 773 9415&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Lab, X-ray, 앰뷸런스 이용 가능 &lt;a href=&quot;http://www.africmed-gm.com/&quot;&gt;www.africmed-gm.com&lt;/a&gt;&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;&lt;br&gt;&#xD;
# &#xD;
# &lt;h3 class=&quot;tit&quot;&gt;대사관 연락처&lt;/h3&gt;&#xD;
# ※ 감비아에는 우리대사관이 없으며, 주세네갈한국대사관이 겸임하고 있습니다.&lt;br&gt;&#xD;
# ㅇ 주소 : Ambassade de la Republique de Coree, Villa Hamoudy, Rue Aim Csaire, Fann Rsidence, B.P.5850, Dakar, Sngal&lt;br&gt;&#xD;
# ㅇ 이메일 : &lt;a href=&quot;mailto:senegal@mofa.go.kr&quot;&gt;senegal@mofa.go.kr&lt;/a&gt; &lt;br&gt;&#xD;
# ㅇ 대표번호 : (+221) 33-824-0672 &lt;br&gt;&#xD;
# ㅇ 긴급연락처 : (+221) 78-184-5554&lt;br&gt;&#xD;
# ㅇ 팩스번호 : (+221) 33 824 0695&lt;br&gt;&lt;/div&gt;</contact><continent>중동/아프리카</continent><countryEnName>Gambia</countryEnName><countryName>감비아</countryName><id>5</id><imgUrl>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_5&amp;file_sn=1</imgUrl><imgUrl2>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_5&amp;file_sn=3</imgUrl2><wrtDt>2011-01-31</wrtDt></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>1</totalCount></body></response>
# <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>HTTP_ERROR</returnAuthMsg>
# 		<returnReasonCode>04</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_ServiceResponse>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items/><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>0</totalCount></body></response>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><contact>&lt;div&gt;&lt;h3 class=&quot;tit marz&quot;&gt;긴급 연락처&lt;/h3&gt;ㅇ 범죄신고 : 110, 120&lt;br&gt;&#xD;
# ㅇ 화재신고 : 122, 123&lt;br&gt;&#xD;
# ㅇ 응급환자 : 128&lt;br&gt;&#xD;
# ㅇ 911 구조대 : 2362-5157 / 2362-5177&lt;br&gt;&#xD;
# ㅇ 전화번호 안내 : 2333-1524&lt;br&gt;&#xD;
# ㅇ 교통경찰 : 1551&lt;br&gt;&#xD;
# ㅇ 아우로라 공한 : 2260-6257&lt;br&gt;&#xD;
# ㅇ 주요 경찰서(관할 구역)&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 경찰서11 (2232-7579, Zona 1, 2, 3, 4, 8, 9)&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 경찰서12 (7879-9655, Zona 6, 17, 18)&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 경찰서13 (2362-1141, Zona 5, 10, 13, 14, 15, 16)&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 경찰서14 (4042-1455, Zona 7, 11, 12, 21)&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 경찰서15 (6631-9310, Villa Nueva, Amatitlan)&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 경찰서16 (2431-3313, Zona 19, Mixco, San Cristobal)&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &#xD;
# &lt;h3 class=&quot;tit&quot;&gt;의료기관 연락처&lt;/h3&gt;ㅇ 과테말라 주요 국립병원&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Hospital General San Juan de Dios&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 주소 : 1a. Ave. 10-50 Zona 1&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 전화 : 2279-4949&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;- Hospital Roosevelt&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 주소 : Calz. Roosevelt Zona 11&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 전화 : 2471-1441&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ 기타 주요병원&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Centro Medico&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 주소 : 6ta. Ave. 3-47 Zona 10&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 전화 : 2279-4949&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp;- Hospital Herrera Llerandi&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 주소 : 6ta. Ave. 8-71 Zona 10&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 전화 : 2384-5969&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Hospital Novicentro&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 주소 : 17 Ave. 28-01 Zona 11 Colonia Las Charcas&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 전화 : 2442-1204 / 2381-1729&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Hospital Multimedica&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 주소 : Bulv. Vista Hermosa 25-19 5to. Nivel Zona 15, VH1&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 전화 : 2385-7877&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Sanatorio Nuestra Senora del Pilar&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 주소 : 3a. Calle 10-71 Zona 15, Colonia Tecun Uman&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; * 전화 : 2420-0000 / 2279-5000&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &#xD;
# &lt;h3 class=&quot;tit&quot;&gt;대사관 연락처&lt;/h3&gt;ㅇ 주소 : 5a. Ave. 5-55 Zona 14, Europlaza Torre 3, Nivel 7, Guatemala &lt;br&gt;&#xD;
# ㅇ 이메일 : &lt;a href=&quot;mailto:embcor.gt@mofa.go.kr&quot;&gt;embcor.gt@mofa.go.kr&lt;/a&gt;&lt;br&gt;&#xD;
# ㅇ 전화번호 : (502) 2382-4051&lt;br&gt;&#xD;
# ㅇ 긴급연락처 : (502) 5561-9956&lt;br&gt;&#xD;
# ㅇ 팩스 : (502) 2382-4057&lt;br&gt;&#xD;
# ㅇ 근무시간 : 월~금&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 오전 8:30~12:30 / 오후 14:00~17:00&lt;br&gt;&#xD;
# &lt;br&gt;&lt;/div&gt;</contact><continent>미주</continent><countryEnName>Guatemala</countryEnName><countryName>과테말라</countryName><id>7</id><imgUrl>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_7&amp;file_sn=1</imgUrl><imgUrl2>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_7&amp;file_sn=3</imgUrl2><wrtDt>2011-01-28</wrtDt></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>1</totalCount></body></response>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items/><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>0</totalCount></body></response>
#
# <OpenAPI_ServiceResponse>
# 	<cmmMsgHeader>
# 		<errMsg>SERVICE ERROR</errMsg>
# 		<returnAuthMsg>HTTP_ERROR</returnAuthMsg>
# 		<returnReasonCode>04</returnReasonCode>
# 	</cmmMsgHeader>
# </OpenAPI_ServiceResponse>
#
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><contact>&lt;h3 class=&quot;tit&quot;&gt;긴급 연락처&lt;/h3&gt;ㅇ 경찰 : 100 &lt;br&gt;&#xD;
# ㅇ 화재 시 : 199 &lt;br&gt;&#xD;
# ㅇ 긴급의료지원 및 앰뷸런스 요청 : 166 &lt;br&gt;&#xD;
# ㅇ 긴급의료기관 요청 전화 : 1016 &lt;br&gt;&#xD;
# ㅇ 야간 의사 문의 : 1434 &lt;br&gt;&#xD;
# ㅇ 야간 약국 : 14944(공휴일 포함하여 매일신문에 지역별로 공고되고 있음.) &lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &#xD;
# &lt;h3 class=&quot;tit&quot;&gt;의료기관 연락처&lt;/h3&gt;ㅇ Public Hospitals&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ Alexandra Hospital :&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Vassilissis Sofias street 80 and K. Lourou street, 115 28 Ilisia&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Tel: +30 210 338 1100 &lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ Evangelismos: &lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Ipsilantou street 45-47, 106 76 Kolonaki&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - Tel: +30 210 720 1000&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# ㅇ 그리스 약국은 월요일&amp;amp;수요일은 8:00~14:30까지, 화, 목, 금요일은 8:00~14:30 ,17:00~20:00까지 영업함. 요일마다 늦게까지 문을 여는 담당 약국이 정해져 있으며 14944번에 연락을 해서 알아볼 수 있음.&lt;br&gt;&#xD;
# &lt;br&gt;&#xD;
# &#xD;
# &lt;h3 class=&quot;tit&quot;&gt;대사관 연락처&lt;/h3&gt;&lt;p&gt;ㅇ 주소 : 2 -4 Mesogion Ave. Athens Tower A Building, 115 27 Athens, Greece &lt;br&gt;&#xD;
# ㅇ 대표번호 : (30) 210-698-4080&lt;/p&gt;&lt;p&gt;&lt;span style=&quot;line-height: 1.5;&quot;&gt;ㅇ&lt;/span&gt;&lt;span style=&quot;line-height: 1.5;&quot;&gt;&amp;nbsp;&lt;/span&gt;긴급연락처 : (30) 694-611-7098&lt;br&gt;&#xD;
# ㅇ 팩스 : (30-210) 698 4083 &lt;br&gt;&#xD;
# ㅇ E-mail : &lt;a href=&quot;mailto:gremb@mofa.go.kr&quot;&gt;gremb@mofa.go.kr&lt;/a&gt; &lt;br&gt;&#xD;
# ㅇ 근무시간&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 월-금요일 : 8:00~17:00&lt;br&gt;&#xD;
# &amp;nbsp;&amp;nbsp;&amp;nbsp;&amp;nbsp; - 점심시간 : 12:30~13:30 (7~8월은 점심시간 없음) &lt;/p&gt;</contact><continent>유럽</continent><countryEnName>Greece</countryEnName><countryName>그리스</countryName><id>11</id><imgUrl>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_11&amp;file_sn=1</imgUrl><imgUrl2>http://www.0404.go.kr/dev/fileDownload.mofa?atch_file_id=COUNTRY_11&amp;file_sn=3</imgUrl2><wrtDt>2011-01-26</wrtDt></item></items><numOfRows>10</numOfRows><pageNo>1</pageNo><totalCount>1</totalCount></body></response>
